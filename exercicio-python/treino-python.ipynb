# %%
'''' Precisamos imprimir um número para cada andar de um hotel de 20 andares. Porém, o dono do hotel é supersticioso e optou por não ter um 13ro andar.

Escreva um código que imprima todos os números exceto o número 13.
Escreva mais dois códigos que resolvam o mesmo problema, mas dessa vez usando os outros dois tipos de laços de repetição aprendidos.

Como desafio, imprima eles em ordem decrescente (20, 19, 18...)

Trabalhe esse código em seu IDE, suba ele para sua conta no GitHub e compartilhe o link desse projeto no campo ao lado para que outros desenvolvedores possam analisá-lo.'''

print("Utilizando laço FOR sentido crescente.")
for andar in range(1,21):
    
    if andar == 13:
        continue
    print(andar, "º Andar do prédio.")
print()
print("Utilizando laço FOR sentido decrescente.")
for andar in range(20,0,-1):
    
    if andar == 13:
        continue
    print(andar, "º Andar do prédio.")
# Out:
# Utilizando laço FOR sentido crescente.
# 1 º Andar do prédio.
# 2 º Andar do prédio.
# 3 º Andar do prédio.
# 4 º Andar do prédio.
# 5 º Andar do prédio.
# 6 º Andar do prédio.
# 7 º Andar do prédio.
# 8 º Andar do prédio.
# 9 º Andar do prédio.
# 10 º Andar do prédio.
# 11 º Andar do prédio.
# 12 º Andar do prédio.
# 14 º Andar do prédio.
# 15 º Andar do prédio.
# 16 º Andar do prédio.
# 17 º Andar do prédio.
# 18 º Andar do prédio.
# 19 º Andar do prédio.
# 20 º Andar do prédio.
#
# Utilizando laço FOR sentido decrescente.
# 20 º Andar do prédio.
# 19 º Andar do prédio.
# 18 º Andar do prédio.
# 17 º Andar do prédio.
# 16 º Andar do prédio.
# 15 º Andar do prédio.
# 14 º Andar do prédio.
# 12 º Andar do prédio.
# 11 º Andar do prédio.
# 10 º Andar do prédio.
# 9 º Andar do prédio.
# 8 º Andar do prédio.
# 7 º Andar do prédio.
# 6 º Andar do prédio.
# 5 º Andar do prédio.
# 4 º Andar do prédio.
# 3 º Andar do prédio.
# 2 º Andar do prédio.
# 1 º Andar do prédio.

# %%
print("Utilizando laço WHILE sentido crescente.")
andar = 0
while andar < 20:
    andar += 1
    if andar == 13:
        continue
    print(andar, "º Andar do prédio.")
print()
print("Utilizando laço WHILE sentido decrescente.")
andar = 21
while andar > 1:
    andar -= 1
    if andar == 13:
        continue
    print(andar, "º Andar do prédio.")
# Out:
# Utilizando laço WHILE sentido crescente.
# 1 º Andar do prédio.
# 2 º Andar do prédio.
# 3 º Andar do prédio.
# 4 º Andar do prédio.
# 5 º Andar do prédio.
# 6 º Andar do prédio.
# 7 º Andar do prédio.
# 8 º Andar do prédio.
# 9 º Andar do prédio.
# 10 º Andar do prédio.
# 11 º Andar do prédio.
# 12 º Andar do prédio.
# 14 º Andar do prédio.
# 15 º Andar do prédio.
# 16 º Andar do prédio.
# 17 º Andar do prédio.
# 18 º Andar do prédio.
# 19 º Andar do prédio.
# 20 º Andar do prédio.
#
# Utilizando laço WHILE sentido decrescente.
# 20 º Andar do prédio.
# 19 º Andar do prédio.
# 18 º Andar do prédio.
# 17 º Andar do prédio.
# 16 º Andar do prédio.
# 15 º Andar do prédio.
# 14 º Andar do prédio.
# 12 º Andar do prédio.
# 11 º Andar do prédio.
# 10 º Andar do prédio.
# 9 º Andar do prédio.
# 8 º Andar do prédio.
# 7 º Andar do prédio.
# 6 º Andar do prédio.
# 5 º Andar do prédio.
# 4 º Andar do prédio.
# 3 º Andar do prédio.
# 2 º Andar do prédio.
# 1 º Andar do prédio.
